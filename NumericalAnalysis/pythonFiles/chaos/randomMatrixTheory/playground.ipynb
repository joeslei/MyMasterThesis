# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import assoc_laguerre as L
from scipy.special import poch, hyp1f1, factorial

# %%
N = 2 ** 12
beta = 5

# %%
t = np.linspace(0, 10 ** 2, 10 ** 3, endpoint=True)
z = (-beta + 1j * t) / np.sqrt(N)
z_bar = z.conjugate()
z_plus = z + z_bar

# %%
hoge = z ** N
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in power
#   """Entry point for launching an IPython kernel.

# %%
hoge
# Out:
# array([  0. -0.j,  -0. +0.j,   0. -0.j, ..., -inf-infj, -inf-infj,
#        -inf-infj])

# %%
ratio = (beta ** 2 - t ** 2 - 2j * beta * t) / (beta ** 2 + t ** 2)

# %%
plt.plot(t, ratio.real, 'r')
plt.plot(t, ratio.imag, 'b')
plt.show()

# %%
second_term = np.linspace(0 + 0j, 0 + 0j, 10, endpoint=True)

# %%
second_term
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j])

# %%
poch(-5, 2)
# Out:
# 20.0

# %%
hyp1f1(-5, -5.2, 3)
# Out:
# 15.819945679320677

# %%
L(z, 3, -0.5)
# Out:
# array([ 4.66693242e-01+0.j        ,  4.66690089e-01-0.00324287j,
#         4.66680629e-01-0.00648574j,  4.66664862e-01-0.00972861j,
#         4.66642788e-01-0.01297146j,  4.66614407e-01-0.01621429j,
#         4.66579719e-01-0.01945711j,  4.66538724e-01-0.0226999j ,
#         4.66491423e-01-0.02594267j,  4.66437815e-01-0.02918541j,
#         4.66377899e-01-0.03242811j,  4.66311677e-01-0.03567077j,
#         4.66239149e-01-0.03891339j,  4.66160313e-01-0.04215597j,
#         4.66075170e-01-0.04539849j,  4.65983721e-01-0.04864097j,
#         4.65885965e-01-0.05188338j,  4.65781901e-01-0.05512573j,
#         4.65671531e-01-0.05836802j,  4.65554855e-01-0.06161024j,
#         4.65431871e-01-0.06485239j,  4.65302580e-01-0.06809446j,
#         4.65166983e-01-0.07133645j,  4.65025078e-01-0.07457836j,
#         4.64876867e-01-0.07782017j,  4.64722349e-01-0.0810619j ,
#         4.64561524e-01-0.08430353j,  4.64394393e-01-0.08754506j,
# ...

# %%
def generalized_assoc_laguerre(x, n, k):
    p = poch(k + 1, n)
    f = factorial(n, exact=True)
    h = hyp1f1(-n, k + 1, x)

    return p * h / f

# %%
generalized_assoc_laguerre(z, 4, -3.2)
# Out:
# array([-1.52790101e-02+0.00000000e+00j, -1.52789925e-02-4.42169061e-05j,
#        -1.52789394e-02-8.84304523e-05j, -1.52788511e-02-1.32637279e-04j,
#        -1.52787273e-02-1.76834026e-04j, -1.52785682e-02-2.21017333e-04j,
#        -1.52783736e-02-2.65183842e-04j, -1.52781436e-02-3.09330191e-04j,
#        -1.52778781e-02-3.53453021e-04j, -1.52775770e-02-3.97548973e-04j,
#        -1.52772404e-02-4.41614686e-04j, -1.52768681e-02-4.85646800e-04j,
#        -1.52764601e-02-5.29641956e-04j, -1.52760164e-02-5.73596794e-04j,
#        -1.52755368e-02-6.17507953e-04j, -1.52750212e-02-6.61372075e-04j,
#        -1.52744697e-02-7.05185799e-04j, -1.52738820e-02-7.48945766e-04j,
#        -1.52732581e-02-7.92648615e-04j, -1.52725979e-02-8.36290986e-04j,
#        -1.52719013e-02-8.79869521e-04j, -1.52711681e-02-9.23380858e-04j,
#        -1.52703983e-02-9.66821639e-04j, -1.52695917e-02-1.01018850e-03j,
#        -1.52687481e-02-1.05347809e-03j, -1.52678675e-02-1.09668704e-03j,
# ...

# %%
poch(-5.1, 3)
# Out:
# -64.82099999999998
