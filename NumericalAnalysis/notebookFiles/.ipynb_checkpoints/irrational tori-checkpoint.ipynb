# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 2 * np.pi)
omega1 = np.sqrt(111)
omega2 = np.sqrt(7)

# %%
f1 = np.sin(omega1 * t)
f2 = np.sin(omega2 * t)
f = f1 + f2

# %%
plt.plot(t, f)
plt.show()
